# %%
class Config():
    def __init__(self):
        self.project_dir = spark.sql("describe external location `sbit_dev`").select("url").collect()[0][0]
        self.landing = self.project_dir + 'data_zone/'
        self.checkpoint = self.project_dir + 'checkpoints/'
        self.medallion = self.project_dir + 'medallion/'
        self.gx_configs = self.project_dir + 'gx_configs/'
        self.db_name = "sbit_db"
        self.maxFilesPerTrigger = 10
