# %%
dbutils.widgets.dropdown(name = 'env', choices = ['dev', 'uat', 'prod'], defaultValue = 'dev', label = 'select your environment')
env = dbutils.widgets.get('env')

# %%
# %run "./02_setup"

# %%
SH = SetupHelper(env)
SH.cleanup()

# %%
SH.setup()

# %%
SH.validate()

# %%
# %run "./03_history_loader"

# %%
HL = HistoryLoader(env)
HL.load_history()
